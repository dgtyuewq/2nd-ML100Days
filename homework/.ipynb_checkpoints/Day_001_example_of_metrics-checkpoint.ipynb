# %% [markdown]
# # 作業1

# %% [markdown]
# # 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 這組資料想解決的問題如何評估

# %% [markdown]
# # Hint: [Two Sigma: Using News to Predict Stock Movements](https://www.kaggle.com/c/two-sigma-financial-news/overview/description)

# %% [markdown]
# 1. 你選的這組資料為何重要：曾經摸過虛擬貨幣，覺得虛擬貨幣的交易跟股市的交易雷同，認為是否有可能運用同樣的方式，能算出整個匯率走向
# 2. 資料從何而來：市場數據由Intrinio提供。<br />
# Thomson 提供的新聞數據
# 3. 蒐集而來的資料型態為何：
# 4. 這組資料想解決的問題如何評估 評估方式為Linear Regression 題目的 score 在下面
# ![image.png](attachment:image.png)

# %% [markdown]
# # 作業2

# %% [markdown]
# # 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)<br />客戶的滿意度(司機態度，路程是否繞路，價格是否合理，整理舒適度)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)<br />利用叫車APP系統當每位使用者結束搭乘時，給一個簡單的回饋
#
# 3. 蒐集而來的資料型態為何<br />每個問題1-5分給予評分，所有分數加總，如果有特殊的問題可以回饋建言
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)<br />基本上不用驗證，因為回饋的都是使用者直接的感覺

# %% [markdown]
# #### 統計指標實作範例
# ## 常見於迴歸問題的評估指標
# * Mean Absolute Error (MAE)
# * Mean Squared Error (MSE)
#
# ## 常見於分類問題的指標
# * Binary Cross Entropy (CE)
#
# ##### 後面的課程還會有更詳細的說明

# %% [markdown]
# # 作業3

# %% [markdown]
# ##  練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, y_hat):
    sumup=0
    """
    請完成這個 Function 後往下執行
    sumup = 0
    for i in range(len(y)):
        sumup = sumup+(y[i]-y_hat[i])**2
        
    sumup =(1/len(y))*sumup
    """
    sumup = sum((y-y_hat)**2)/len(y)
    return sumup

# %%
def mean_absolute_error(y, y_hat):
    sumup =0
    '''
     for i in range(len(y)):
        sumup = sumup + abs(y[i]-y_hat[i])
    
    sumup =(1/len(y))*sumup
    '''
    sumup = sum(abs(y-y_hat))/len(y)
    return sumup

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# plt.legend(loc = n)
#'''
#'best'         : 0, (only implemented for axes legends)(自适应方式)
#'upper right'  : 1,
#'upper left'   : 2,
#'lower left'   : 3,
#'lower right'  : 4,
#'right'        : 5,
#'center left'  : 6,
#'center right' : 7,
#'lower center' : 8,
#'upper center' : 9,
#'center'       : 10,
#
#'''

# %%
plt.scatter(x=x_lin, y=y ,label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 12.532
